# %% [markdown]
# ## Assignment 1 (due date: 11:59pm, March 3rd, 2023)
# ### Student ID: 20201702
# ### Student Name: Yu Fo Hon

# %%
## load the data from .csv file
import pandas as pd
# load data
df = pd.read_csv("Dry_Bean_Dataset.csv")
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %% [markdown]
# ### Q1. Create a new column named `Sample_ID` (from 1 to N) and set this column as the index of dataframe

# %%
# create a new column with the index from 1 to N
df['Sample_ID'] = list(range(1, len(df) + 1))

# set the new column as the index
df.set_index('Sample_ID', inplace=True)
df
# Out:
#             Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# Sample_ID
# 1          28395    610.291       208.178117       173.888747      1.197191
# 2          28734    638.018       200.524796       182.734419      1.097356
# 3          29380    624.110       212.826130       175.931143      1.209713
# 4          30008    645.884       210.557999       182.516516      1.153638
# 5          30140    620.134       201.847882       190.279279      1.060798
# ...          ...        ...              ...              ...           ...
# 13607      42097    759.696       288.721612       185.944705      1.552728
# 13608      42101    757.499       281.576392       190.713136      1.476439
# 13609      42139    759.321       281.539928       191.187979      1.472582
# 13610      42147    763.779       283.382636       190.275731      1.489326
# 13611      42159    772.237       295.142741       182.204716      1.619841
#
#            Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  \
# Sample_ID
# 1              0.549812       28715     190.141097  0.763923  0.988856
# 2              0.411785       29172     191.272751  0.783968  0.984986
# 3              0.562727       29690     193.410904  0.778113  0.989559
# 4              0.498616       30724     195.467062  0.782681  0.976696
# 5              0.333680       30417     195.896503  0.773098  0.990893
# ...                 ...         ...            ...       ...       ...
# 13607          0.765002       42508     231.515799  0.714574  0.990331
# 13608          0.735702       42494     231.526798  0.799943  0.990752
# 13609          0.734065       42569     231.631261  0.729932  0.989899
# 13610          0.741055       42667     231.653247  0.705389  0.987813
# 13611          0.786693       42600     231.686223  0.788962  0.989648
#
#            roundness  Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  \
# Sample_ID
# 1           0.958027     0.913358      0.007332      0.003147      0.834222
# 2           0.887034     0.953861      0.006979      0.003564      0.909851
# 3           0.947849     0.908774      0.007244      0.003048      0.825871
# 4           0.903936     0.928329      0.007017      0.003215      0.861794
# 5           0.984877     0.970516      0.006697      0.003665      0.941900
# ...              ...          ...           ...           ...           ...
# 13607       0.916603     0.801865      0.006858      0.001749      0.642988
# 13608       0.922015     0.822252      0.006688      0.001886      0.676099
# 13609       0.918424     0.822730      0.006681      0.001888      0.676884
# 13610       0.907906     0.817457      0.006724      0.001852      0.668237
# 13611       0.888380     0.784997      0.007001      0.001640      0.616221
#
#            ShapeFactor4     Class
# Sample_ID
# 1              0.998724     SEKER
# 2              0.998430     SEKER
# 3              0.999066     SEKER
# 4              0.994199     SEKER
# 5              0.999166     SEKER
# ...                 ...       ...
# 13607          0.998385  DERMASON
# 13608          0.998219  DERMASON
# 13609          0.996767  DERMASON
# 13610          0.995222  DERMASON
# 13611          0.998180  DERMASON
#
# [13611 rows x 17 columns]

# %% [markdown]
# ### Q2. How many instances of each bean class are in the dataset?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13611 entries, 1 to 13611
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Q3. How many beans of each class have a `Solidity` greater than 0.8 and a `Compactness` greater than 0.5?

# %% [markdown]
# ### Q4. How does the mean `Area` of each bean class and the overall mean `Area` of all beans in the dataset?

# %% [markdown]
# ### Q5. How can I create a pivot table that shows the mean `Area` and `Solidity` values for each bin class?

# %% [markdown]
# ### Q6. Separate all beans into three types based on MajorAxisLength and create a new column named `MajorAxisLength_Type`
#
# Type_1: `MajorAxisLength<250`
#
# Type_2: `250<=MajorAxisLength<400`
#
# Type_3: `MajorAxisLength>=400`

# %% [markdown]
# ### Q7. Drop all the rows labeled as `MajorAxisLength_Type=Type_1`

# %% [markdown]
# ### Q8. How can I create a pivot table that shows the median `Eccentricity` and `AspectRatio` values for each `Class` and `MajorAxisLength_Type`

# %% [markdown]
# ### Q9. Convert the `Class` using one-hot encoding and merge the new column into the original dataframe

# %% [markdown]
# ### Q10. Apply min-max normalization to `ConvexArea` and `EquivDiameter`

# %% [markdown]
# ### Q11. Generate a scatter plot between `MajorAxisLength` and `MinorAxisLength`; Are they positive, negative or no correlated each other?
